# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulrit25/pythonlab/blob/main/10_12_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([3,8,5,7])

plt.plot(ypoints,color="yellow")
plt.show()
